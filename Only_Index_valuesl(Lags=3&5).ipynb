# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
csv_file_path = '/content/drive/MyDrive/Capstone Data/Copy of NIFTY 50-01-01-2021-to-31-12-2021.csv'

# %%
df_21 = pd.read_csv(csv_file_path)

# %%
df_21
# Out:
#            Date      Open      High       Low     Close   Shares Traded   \
# 0    01-JAN-2021  13996.10  14049.85  13991.35  14018.50       258090905
# 1    04-JAN-2021  14104.35  14147.95  13953.75  14132.90       494999295
# 2    05-JAN-2021  14075.15  14215.60  14048.15  14199.50       492475349
# 3    06-JAN-2021  14240.95  14244.15  14039.90  14146.25       632323316
# 4    07-JAN-2021  14253.75  14256.25  14123.10  14137.35       559173512
# ..           ...       ...       ...       ...       ...             ...
# 243  27-DEC-2021  16937.75  17112.05  16833.20  17086.25       144777457
# 244  28-DEC-2021  17177.60  17250.25  17161.15  17233.25       176026100
# 245  29-DEC-2021  17220.10  17285.95  17176.65  17213.60       161679423
# 246  30-DEC-2021  17201.45  17264.05  17146.35  17203.95       320831676
# 247  31-DEC-2021  17244.50  17400.80  17238.50  17354.05       167025720
#
#      Turnover (₹ Cr)
# 0           15873.75
# 1           28705.09
# 2           30872.87
# 3           34615.55
# 4           33446.47
# ..               ...
# 243         12567.03
# 244         14553.76
# 245         14320.79
# 246         21929.19
# 247         14588.54
#
# [248 rows x 7 columns]

# %%
df_21['Date '] = pd.to_datetime(df_21['Date '], format='%d-%b-%Y')

# Display the DataFrame info to verify the changes

# %%
csv_file_path1 = '/content/drive/MyDrive/Capstone Data/Copy of NIFTY 50-01-01-2023-to-31-12-2023.csv'

# %%
df_23 = pd.read_csv(csv_file_path1)

# %%
df_23
# Out:
#           Date      Open      High       Low     Close   Shares Traded   \
# 0    02-01-2023  18131.70  18215.15  18086.50  18197.45       256073979
# 1    03-01-2023  18163.20  18251.95  18149.80  18232.55       208699772
# 2    04-01-2023  18230.65  18243.00  18020.60  18042.95       235162202
# 3    05-01-2023  18101.95  18120.30  17892.60  17992.15       269949738
# 4    06-01-2023  18008.05  18047.40  17795.55  17859.45       238220578
# ..          ...       ...       ...       ...       ...             ...
# 241  22-12-2023  21295.85  21390.50  21232.45  21349.40       284708918
# 242  26-12-2023  21365.20  21477.15  21329.45  21441.35       219467748
# 243  27-12-2023  21497.65  21675.75  21495.80  21654.75       256542963
# 244  28-12-2023  21715.00  21801.45  21678.00  21778.70       393080755
# 245  29-12-2023  21737.65  21770.30  21676.90  21731.40       270922276
#
#      Turnover (₹ Cr)
# 0           11793.06
# 1           13680.91
# 2           16687.71
# 3           22108.53
# 4           17495.25
# ..               ...
# 241         27709.29
# 242         20081.33
# 243         23059.25
# 244         35031.00
# 245         23697.88
#
# [246 rows x 7 columns]

# %%
csv_file_path2 = '/content/drive/MyDrive/Capstone Data/Copy of NIFTY 50-01-01-2022-to-31-12-2022.csv'

# %%
df_22 = pd.read_csv(csv_file_path2)

# %%
df_22
# Out:
#           Date      Open      High       Low     Close   Shares Traded   \
# 0    03-01-2022  17387.15  17646.65  17383.30  17625.70       200456430
# 1    04-01-2022  17681.40  17827.60  17593.55  17805.25       247437472
# 2    05-01-2022  17820.10  17944.70  17748.85  17925.25       251460038
# 3    06-01-2022  17768.50  17797.95  17655.55  17745.90       236454824
# 4    07-01-2022  17797.60  17905.00  17704.55  17812.70       239338015
# ..          ...       ...       ...       ...       ...             ...
# 243  26-12-2022  17830.40  18084.10  17774.25  18014.60       176652342
# 244  27-12-2022  18089.80  18149.25  17967.45  18132.30       214257094
# 245  28-12-2022  18084.75  18173.10  18068.35  18122.50       193873167
# 246  29-12-2022  18045.70  18229.70  17992.80  18191.00       281052828
# 247  30-12-2022  18259.10  18265.25  18080.30  18105.30       192005563
#
#      Turnover (₹ Cr)
# 0           16181.36
# 1           18604.16
# 2           23737.31
# 3           22643.82
# 4           21447.89
# ..               ...
# 243         13708.21
# 244         13000.64
# 245         13997.59
# 246         18466.05
# 247         14475.22
#
# [248 rows x 7 columns]

# %%
csv_file_path3 = '/content/drive/MyDrive/Capstone Data/Copy of NIFTY 50-01-01-2024-to-16-02-2024.csv'

# %%
df_24_1 = pd.read_csv(csv_file_path3)

# %%
df_24_1
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0   01-01-2024  21727.75  21834.35  21680.85  21741.90     153995217.0
# 1   02-01-2024  21751.35  21755.60  21555.65  21665.80     263711568.0
# 2   03-01-2024  21661.10  21677.00  21500.35  21517.35     311933117.0
# 3   04-01-2024  21605.80  21685.65  21564.55  21658.60     339172697.0
# 4   05-01-2024  21705.75  21749.60  21629.20  21710.80     309303266.0
# 5   08-01-2024  21747.60  21763.95  21492.90  21513.00     231452935.0
# 6   09-01-2024  21653.60  21724.45  21517.85  21544.85     228568589.0
# 7   10-01-2024  21529.30  21641.85  21448.65  21618.70     216991926.0
# 8   11-01-2024  21688.00  21726.50  21593.75  21647.20     212453866.0
# 9   12-01-2024  21773.55  21928.25  21715.15  21894.55     294678459.0
# 10  15-01-2024  22053.15  22115.55  21963.55  22097.45     345543523.0
# 11  16-01-2024  22080.50  22124.15  21969.80  22032.30     292433764.0
# 12  17-01-2024  21647.25  21851.50  21550.45  21571.95     455999867.0
# 13  18-01-2024  21414.20  21539.40  21285.55  21462.25     387341268.0
# 14  19-01-2024  21615.20  21670.60  21575.00  21622.40     343055124.0
# 15  20-01-2024  21706.15  21720.30  21541.80  21571.80     162073740.0
# 16  23-01-2024  21716.70  21750.25  21192.60  21238.80     449718534.0
# 17  24-01-2024  21185.25  21482.35  21137.20  21453.95     407460664.0
# 18  25-01-2024  21454.60  21459.00  21247.05  21352.60     418143077.0
# 19  29-01-2024  21433.10  21763.25  21429.60  21737.60     376702289.0
# 20  30-01-2024  21775.75  21813.05  21501.80  21522.10     375137333.0
# 21  31-01-2024  21487.25  21741.35  21448.85  21725.70     410583065.0
# 22  01-02-2024  21780.65  21832.95  21658.75  21697.45     332541208.0
# 23  02-02-2024  21812.75  22126.80  21805.55  21853.80     442794738.0
# 24  05-02-2024  21921.05  21964.30  21726.95  21771.70     440849699.0
# 25  06-02-2024  21825.20  21951.40  21737.55  21929.40     370968111.0
# 26  07-02-2024  22045.05  22053.30  21860.15  21930.50     346263704.0
# 27  08-02-2024  22009.65  22011.05  21665.30  21717.95     491069786.0
# 28  09-02-2024  21727.00  21804.45  21629.90  21782.50     349222850.0
# 29  12-02-2024  21800.80  21831.70  21574.75  21616.05     287436165.0
# 30  13-02-2024  21664.30  21766.80  21543.35  21743.25     365785766.0
# 31  14-02-2024  21578.15  21870.85  21530.20  21840.05     359120861.0
# 32  15-02-2024  21906.55  21953.85  21794.80  21910.75     345394395.0
# 33  16-02-2024  22020.30  22068.65  21968.95  22040.70             NaN
#
#     Turnover (₹ Cr)
# 0          14184.09
# 1          25316.13
# 2          32329.23
# 3          30868.15
# 4          26554.49
# 5          21140.94
# 6          24055.74
# 7          20958.96
# 8          23492.12
# 9          30565.50
# 10         29523.15
# 11         24435.94
# 12         47533.44
# 13         39718.84
# 14         34429.24
# 15         13917.46
# 16         48813.68
# 17         41718.64
# 18         40088.50
# 19         34516.42
# 20         32916.30
# 21         41587.85
# 22         34042.15
# 23         38395.90
# 24         33807.94
# 25         32910.82
# 26         30088.76
# 27         41082.02
# 28         31176.16
# 29         23921.14
# 30         29896.62
# 31         32535.00
# 32         29559.69
# 33              NaN

# %%
csv_file_path4 = '/content/drive/MyDrive/Capstone Data/Copy of NIFTY 50-19-02-2024-to-22-02-2024.csv'

# %%
df_24_2 = pd.read_csv(csv_file_path4)

# %%
df_24_2
# Out:
#         Date      Open      High       Low     Close   Shares Traded   \
# 0   19-Feb-24  22103.45  22186.65  22021.05  22122.25     218252325.0
# 1   20-Feb-24  22099.20  22215.60  22045.85  22196.95     295705319.0
# 2   21-Feb-24  22248.85  22249.40  21997.95  22055.05     364545679.0
# 3   22-Feb-24  22081.55  22252.50  21875.25  22217.45     343495136.0
# 4         NaN       NaN       NaN       NaN       NaN             NaN
# 5         NaN       NaN       NaN       NaN       NaN             NaN
# 6         NaN       NaN       NaN       NaN       NaN             NaN
# 7         NaN       NaN       NaN       NaN       NaN             NaN
# 8         NaN       NaN       NaN       NaN       NaN             NaN
# 9         NaN       NaN       NaN       NaN       NaN             NaN
# 10        NaN       NaN       NaN       NaN       NaN             NaN
# 11        NaN       NaN       NaN       NaN       NaN             NaN
# 12        NaN       NaN       NaN       NaN       NaN             NaN
# 13        NaN       NaN       NaN       NaN       NaN             NaN
# 14        NaN       NaN       NaN       NaN       NaN             NaN
# 15        NaN       NaN       NaN       NaN       NaN             NaN
# 16        NaN       NaN       NaN       NaN       NaN             NaN
# 17        NaN       NaN       NaN       NaN       NaN             NaN
# 18        NaN       NaN       NaN       NaN       NaN             NaN
# 19        NaN       NaN       NaN       NaN       NaN             NaN
# 20        NaN       NaN       NaN       NaN       NaN             NaN
# 21        NaN       NaN       NaN       NaN       NaN             NaN
# 22        NaN       NaN       NaN       NaN       NaN             NaN
# 23        NaN       NaN       NaN       NaN       NaN             NaN
# 24        NaN       NaN       NaN       NaN       NaN             NaN
# 25        NaN       NaN       NaN       NaN       NaN             NaN
# 26        NaN       NaN       NaN       NaN       NaN             NaN
# 27        NaN       NaN       NaN       NaN       NaN             NaN
# 28        NaN       NaN       NaN       NaN       NaN             NaN
# 29        NaN       NaN       NaN       NaN       NaN             NaN
# 30        NaN       NaN       NaN       NaN       NaN             NaN
# 31        NaN       NaN       NaN       NaN       NaN             NaN
# 32        NaN       NaN       NaN       NaN       NaN             NaN
# 33        NaN       NaN       NaN       NaN       NaN             NaN
# 34        NaN       NaN       NaN       NaN       NaN             NaN
# 35        NaN       NaN       NaN       NaN       NaN             NaN
# 36        NaN       NaN       NaN       NaN       NaN             NaN
# 37        NaN       NaN       NaN       NaN       NaN             NaN
# 38        NaN       NaN       NaN       NaN       NaN             NaN
# 39        NaN       NaN       NaN       NaN       NaN             NaN
# 40        NaN       NaN       NaN       NaN       NaN             NaN
# 41        NaN       NaN       NaN       NaN       NaN             NaN
# 42        NaN       NaN       NaN       NaN       NaN             NaN
#
#     Turnover (₹ Cr)
# 0          21375.71
# 1          26872.32
# 2          29741.39
# 3          33985.94
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41              NaN
# 42              NaN

# %%
df_24_2.dropna(inplace=True)

# %%
index_df = pd.concat([df_21, df_22, df_23, df_24_1, df_24_2], axis=0)
index_df.reset_index(drop=True, inplace=True)

# %%
index_df
# Out:
#                    Date      Open      High       Low     Close   \
# 0    2021-01-01 00:00:00  13996.10  14049.85  13991.35  14018.50
# 1    2021-01-04 00:00:00  14104.35  14147.95  13953.75  14132.90
# 2    2021-01-05 00:00:00  14075.15  14215.60  14048.15  14199.50
# 3    2021-01-06 00:00:00  14240.95  14244.15  14039.90  14146.25
# 4    2021-01-07 00:00:00  14253.75  14256.25  14123.10  14137.35
# ..                   ...       ...       ...       ...       ...
# 775           16-02-2024  22020.30  22068.65  21968.95  22040.70
# 776            19-Feb-24  22103.45  22186.65  22021.05  22122.25
# 777            20-Feb-24  22099.20  22215.60  22045.85  22196.95
# 778            21-Feb-24  22248.85  22249.40  21997.95  22055.05
# 779            22-Feb-24  22081.55  22252.50  21875.25  22217.45
#
#      Shares Traded   Turnover (₹ Cr)
# 0       258090905.0         15873.75
# 1       494999295.0         28705.09
# 2       492475349.0         30872.87
# 3       632323316.0         34615.55
# 4       559173512.0         33446.47
# ..              ...              ...
# 775             NaN              NaN
# 776     218252325.0         21375.71
# 777     295705319.0         26872.32
# 778     364545679.0         29741.39
# 779     343495136.0         33985.94
#
# [780 rows x 7 columns]

# %%
#Change the date time format
def parse_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y', errors='raise')
    except ValueError:
        return pd.to_datetime(date_str, errors='coerce')

# Apply the custom function to the 'Date' column
index_df['Date '] = index_df['Date '].apply(parse_date)

# %%
index_df
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0   2021-01-01  13996.10  14049.85  13991.35  14018.50     258090905.0
# 1   2021-01-04  14104.35  14147.95  13953.75  14132.90     494999295.0
# 2   2021-01-05  14075.15  14215.60  14048.15  14199.50     492475349.0
# 3   2021-01-06  14240.95  14244.15  14039.90  14146.25     632323316.0
# 4   2021-01-07  14253.75  14256.25  14123.10  14137.35     559173512.0
# ..         ...       ...       ...       ...       ...             ...
# 775 2024-02-16  22020.30  22068.65  21968.95  22040.70             NaN
# 776 2024-02-19  22103.45  22186.65  22021.05  22122.25     218252325.0
# 777 2024-02-20  22099.20  22215.60  22045.85  22196.95     295705319.0
# 778 2024-02-21  22248.85  22249.40  21997.95  22055.05     364545679.0
# 779 2024-02-22  22081.55  22252.50  21875.25  22217.45     343495136.0
#
#      Turnover (₹ Cr)
# 0           15873.75
# 1           28705.09
# 2           30872.87
# 3           34615.55
# 4           33446.47
# ..               ...
# 775              NaN
# 776         21375.71
# 777         26872.32
# 778         29741.39
# 779         33985.94
#
# [780 rows x 7 columns]

# %%
index_df.drop(['Shares Traded ', 'Turnover (₹ Cr)'], axis=1, inplace=True)
index_df
# Out:
#          Date      Open      High       Low     Close
# 0   2021-01-01  13996.10  14049.85  13991.35  14018.50
# 1   2021-01-04  14104.35  14147.95  13953.75  14132.90
# 2   2021-01-05  14075.15  14215.60  14048.15  14199.50
# 3   2021-01-06  14240.95  14244.15  14039.90  14146.25
# 4   2021-01-07  14253.75  14256.25  14123.10  14137.35
# ..         ...       ...       ...       ...       ...
# 775 2024-02-16  22020.30  22068.65  21968.95  22040.70
# 776 2024-02-19  22103.45  22186.65  22021.05  22122.25
# 777 2024-02-20  22099.20  22215.60  22045.85  22196.95
# 778 2024-02-21  22248.85  22249.40  21997.95  22055.05
# 779 2024-02-22  22081.55  22252.50  21875.25  22217.45
#
# [780 rows x 5 columns]

# %%
index_df['Close '].mean()
# Out:
# 17600.0016025641

# %%
index_df.isna().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# dtype: int64

# %%
import pandas as pd

# Assuming index_df is your DataFrame

# Splitting into train and test DataFrames
train_index = index_df.iloc[:580]
test_index = index_df.iloc[580:]

# Displaying the first few rows of each DataFrame
print("Train DataFrame:")
print(train_index.head())

print("\nTest DataFrame:")
print(test_index.head())
# Out:
# Train DataFrame:
#        Date      Open      High       Low     Close
# 0 2021-01-01  13996.10  14049.85  13991.35  14018.50
# 1 2021-01-04  14104.35  14147.95  13953.75  14132.90
# 2 2021-01-05  14075.15  14215.60  14048.15  14199.50
# 3 2021-01-06  14240.95  14244.15  14039.90  14146.25
# 4 2021-01-07  14253.75  14256.25  14123.10  14137.35
#
# Test DataFrame:
#          Date      Open      High       Low     Close
# 580 2023-05-09  18303.40  18344.20  18229.65  18265.95
# 581 2023-05-10  18313.60  18326.75  18211.95  18315.10
# 582 2023-05-11  18357.80  18389.70  18270.40  18297.00
# 583 2023-05-12  18273.75  18342.75  18194.55  18314.80
# 584 2023-05-15  18339.30  18458.90  18287.90  18398.85

# %%
date_column = train_index['Date ']
index_values = train_index[['Open ', 'High ', 'Low ', 'Close ']]

# %%
lagged_topics = pd.DataFrame()
for column in train_index.columns:
  for i in range(1, 6):
    lagged_topics[f'{column}_lag{i}'] = train_index[column].shift(i)

# %%
train_index = pd.concat([date_column, lagged_topics, index_values], axis=1)

# %%
train_index.columns
# Out:
# Index(['Date ', 'Date _lag1', 'Date _lag2', 'Date _lag3', 'Date _lag4',
#        'Date _lag5', 'Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
#        'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
#        'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
#        'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
#        'Close _lag5', 'Open ', 'High ', 'Low ', 'Close '],
#       dtype='object')

# %%
columns_to_drop1 = ['Date _lag1', 'Date _lag2', 'Date _lag3', 'Date _lag4',
       'Date _lag5']
train_index.drop(columns=columns_to_drop1, inplace=True)

# %%
train_index
# Out:
#          Date   Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  \
# 0   2021-01-01         NaN         NaN         NaN         NaN         NaN
# 1   2021-01-04    13996.10         NaN         NaN         NaN         NaN
# 2   2021-01-05    14104.35    13996.10         NaN         NaN         NaN
# 3   2021-01-06    14075.15    14104.35    13996.10         NaN         NaN
# 4   2021-01-07    14240.95    14075.15    14104.35    13996.10         NaN
# ..         ...         ...         ...         ...         ...         ...
# 575 2023-05-02    17950.40    17813.10    17767.30    17761.55    17707.55
# 576 2023-05-03    18124.80    17950.40    17813.10    17767.30    17761.55
# 577 2023-05-04    18113.80    18124.80    17950.40    17813.10    17767.30
# 578 2023-05-05    18081.00    18113.80    18124.80    17950.40    17813.10
# 579 2023-05-08    18117.30    18081.00    18113.80    18124.80    17950.40
#
#      High _lag1  High _lag2  High _lag3  High _lag4  ...  Low _lag5  \
# 0           NaN         NaN         NaN         NaN  ...        NaN
# 1      14049.85         NaN         NaN         NaN  ...        NaN
# 2      14147.95    14049.85         NaN         NaN  ...        NaN
# 3      14215.60    14147.95    14049.85         NaN  ...        NaN
# 4      14244.15    14215.60    14147.95    14049.85  ...        NaN
# ..          ...         ...         ...         ...  ...        ...
# 575    18089.15    17931.60    17827.75    17807.45  ...   17612.50
# 576    18180.25    18089.15    17931.60    17827.75  ...   17716.85
# 577    18116.35    18180.25    18089.15    17931.60  ...   17711.20
# 578    18267.45    18116.35    18180.25    18089.15  ...   17797.90
# 579    18216.95    18267.45    18116.35    18180.25  ...   17885.30
#
#      Close _lag1  Close _lag2  Close _lag3  Close _lag4  Close _lag5  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1       14018.50          NaN          NaN          NaN          NaN
# 2       14132.90     14018.50          NaN          NaN          NaN
# 3       14199.50     14132.90     14018.50          NaN          NaN
# 4       14146.25     14199.50     14132.90     14018.50          NaN
# ..           ...          ...          ...          ...          ...
# 575     18065.00     17915.05     17813.60     17769.25     17743.40
# 576     18147.65     18065.00     17915.05     17813.60     17769.25
# 577     18089.85     18147.65     18065.00     17915.05     17813.60
# 578     18255.80     18089.85     18147.65     18065.00     17915.05
# 579     18069.00     18255.80     18089.85     18147.65     18065.00
#
#         Open      High       Low     Close
# 0    13996.10  14049.85  13991.35  14018.50
# 1    14104.35  14147.95  13953.75  14132.90
# 2    14075.15  14215.60  14048.15  14199.50
# 3    14240.95  14244.15  14039.90  14146.25
# 4    14253.75  14256.25  14123.10  14137.35
# ..        ...       ...       ...       ...
# 575  18124.80  18180.25  18101.75  18147.65
# 576  18113.80  18116.35  18042.40  18089.85
# 577  18081.00  18267.45  18066.70  18255.80
# 578  18117.30  18216.95  18055.45  18069.00
# 579  18120.60  18286.95  18100.30  18264.40
#
# [580 rows x 25 columns]

# %%
train_index = train_index.iloc[5:]
train_index.reset_index(drop=True, inplace=True)

# %%
train_index
# Out:
#          Date   Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  \
# 0   2021-01-08    14253.75    14240.95    14075.15    14104.35    13996.10
# 1   2021-01-11    14258.40    14253.75    14240.95    14075.15    14104.35
# 2   2021-01-12    14474.05    14258.40    14253.75    14240.95    14075.15
# 3   2021-01-13    14473.80    14474.05    14258.40    14253.75    14240.95
# 4   2021-01-14    14639.80    14473.80    14474.05    14258.40    14253.75
# ..         ...         ...         ...         ...         ...         ...
# 570 2023-05-02    17950.40    17813.10    17767.30    17761.55    17707.55
# 571 2023-05-03    18124.80    17950.40    17813.10    17767.30    17761.55
# 572 2023-05-04    18113.80    18124.80    17950.40    17813.10    17767.30
# 573 2023-05-05    18081.00    18113.80    18124.80    17950.40    17813.10
# 574 2023-05-08    18117.30    18081.00    18113.80    18124.80    17950.40
#
#      High _lag1  High _lag2  High _lag3  High _lag4  ...  Low _lag5  \
# 0      14256.25    14244.15    14215.60    14147.95  ...   13991.35
# 1      14367.30    14256.25    14244.15    14215.60  ...   13953.75
# 2      14498.20    14367.30    14256.25    14244.15  ...   14048.15
# 3      14590.65    14498.20    14367.30    14256.25  ...   14039.90
# 4      14653.35    14590.65    14498.20    14367.30  ...   14123.10
# ..          ...         ...         ...         ...  ...        ...
# 570    18089.15    17931.60    17827.75    17807.45  ...   17612.50
# 571    18180.25    18089.15    17931.60    17827.75  ...   17716.85
# 572    18116.35    18180.25    18089.15    17931.60  ...   17711.20
# 573    18267.45    18116.35    18180.25    18089.15  ...   17797.90
# 574    18216.95    18267.45    18116.35    18180.25  ...   17885.30
#
#      Close _lag1  Close _lag2  Close _lag3  Close _lag4  Close _lag5  \
# 0       14137.35     14146.25     14199.50     14132.90     14018.50
# 1       14347.25     14137.35     14146.25     14199.50     14132.90
# 2       14484.75     14347.25     14137.35     14146.25     14199.50
# 3       14563.45     14484.75     14347.25     14137.35     14146.25
# 4       14564.85     14563.45     14484.75     14347.25     14137.35
# ..           ...          ...          ...          ...          ...
# 570     18065.00     17915.05     17813.60     17769.25     17743.40
# 571     18147.65     18065.00     17915.05     17813.60     17769.25
# 572     18089.85     18147.65     18065.00     17915.05     17813.60
# 573     18255.80     18089.85     18147.65     18065.00     17915.05
# 574     18069.00     18255.80     18089.85     18147.65     18065.00
#
#         Open      High       Low     Close
# 0    14258.40  14367.30  14221.65  14347.25
# 1    14474.05  14498.20  14383.10  14484.75
# 2    14473.80  14590.65  14432.85  14563.45
# 3    14639.80  14653.35  14435.70  14564.85
# 4    14550.05  14617.80  14471.50  14595.60
# ..        ...       ...       ...       ...
# 570  18124.80  18180.25  18101.75  18147.65
# 571  18113.80  18116.35  18042.40  18089.85
# 572  18081.00  18267.45  18066.70  18255.80
# 573  18117.30  18216.95  18055.45  18069.00
# 574  18120.60  18286.95  18100.30  18264.40
#
# [575 rows x 25 columns]

# %%
date_column1 = test_index['Date ']
index_values1 = test_index[['Open ', 'High ', 'Low ', 'Close ']]

# %%
lagged_topics1 = pd.DataFrame()
for column in test_index.columns:
  for i in range(1, 6):
    lagged_topics1[f'{column}_lag{i}'] = test_index[column].shift(i)

# %%
test_index = pd.concat([date_column1, lagged_topics1, index_values1], axis=1)

# %%
columns_to_drop2 = ['Date _lag1', 'Date _lag2', 'Date _lag3', 'Date _lag4',
       'Date _lag5']
test_index.drop(columns=columns_to_drop2, inplace=True)

# %%
test_index = test_index.iloc[3:]
test_index.reset_index(drop=True, inplace=True)

# %%
test_index = test_index.iloc[2:]
test_index.reset_index(drop=True, inplace=True)

# %%
test_index
# Out:
#          Date   Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  \
# 0   2023-05-16    18339.30    18273.75    18357.80    18313.60    18303.40
# 1   2023-05-17    18432.35    18339.30    18273.75    18357.80    18313.60
# 2   2023-05-18    18300.45    18432.35    18339.30    18273.75    18357.80
# 3   2023-05-19    18287.50    18300.45    18432.35    18339.30    18273.75
# 4   2023-05-22    18186.15    18287.50    18300.45    18432.35    18339.30
# ..         ...         ...         ...         ...         ...         ...
# 190 2024-02-16    21906.55    21578.15    21664.30    21800.80    21727.00
# 191 2024-02-19    22020.30    21906.55    21578.15    21664.30    21800.80
# 192 2024-02-20    22103.45    22020.30    21906.55    21578.15    21664.30
# 193 2024-02-21    22099.20    22103.45    22020.30    21906.55    21578.15
# 194 2024-02-22    22248.85    22099.20    22103.45    22020.30    21906.55
#
#      High _lag1  High _lag2  High _lag3  High _lag4  ...  Low _lag5  \
# 0      18458.90    18342.75    18389.70    18326.75  ...   18229.65
# 1      18432.35    18458.90    18342.75    18389.70  ...   18211.95
# 2      18309.00    18432.35    18458.90    18342.75  ...   18270.40
# 3      18297.20    18309.00    18432.35    18458.90  ...   18194.55
# 4      18218.10    18297.20    18309.00    18432.35  ...   18287.90
# ..          ...         ...         ...         ...  ...        ...
# 190    21953.85    21870.85    21766.80    21831.70  ...   21629.90
# 191    22068.65    21953.85    21870.85    21766.80  ...   21574.75
# 192    22186.65    22068.65    21953.85    21870.85  ...   21543.35
# 193    22215.60    22186.65    22068.65    21953.85  ...   21530.20
# 194    22249.40    22215.60    22186.65    22068.65  ...   21794.80
#
#      Close _lag1  Close _lag2  Close _lag3  Close _lag4  Close _lag5  \
# 0       18398.85     18314.80     18297.00     18315.10     18265.95
# 1       18286.50     18398.85     18314.80     18297.00     18315.10
# 2       18181.75     18286.50     18398.85     18314.80     18297.00
# 3       18129.95     18181.75     18286.50     18398.85     18314.80
# 4       18203.40     18129.95     18181.75     18286.50     18398.85
# ..           ...          ...          ...          ...          ...
# 190     21910.75     21840.05     21743.25     21616.05     21782.50
# 191     22040.70     21910.75     21840.05     21743.25     21616.05
# 192     22122.25     22040.70     21910.75     21840.05     21743.25
# 193     22196.95     22122.25     22040.70     21910.75     21840.05
# 194     22055.05     22196.95     22122.25     22040.70     21910.75
#
#         Open      High       Low     Close
# 0    18432.35  18432.35  18264.35  18286.50
# 1    18300.45  18309.00  18115.35  18181.75
# 2    18287.50  18297.20  18104.85  18129.95
# 3    18186.15  18218.10  18060.40  18203.40
# 4    18201.10  18335.25  18178.85  18314.40
# ..        ...       ...       ...       ...
# 190  22020.30  22068.65  21968.95  22040.70
# 191  22103.45  22186.65  22021.05  22122.25
# 192  22099.20  22215.60  22045.85  22196.95
# 193  22248.85  22249.40  21997.95  22055.05
# 194  22081.55  22252.50  21875.25  22217.45
#
# [195 rows x 25 columns]

# %%
train_index.columns
# Out:
# Index(['Date ', 'Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
#        'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
#        'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
#        'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
#        'Close _lag5', 'Open ', 'High ', 'Low ', 'Close '],
#       dtype='object')

# %%
test_index.columns
# Out:
# Index(['Date ', 'Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
#        'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
#        'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
#        'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
#        'Close _lag5', 'Open ', 'High ', 'Low ', 'Close '],
#       dtype='object')

# %%
train_data = train_index
test_data = test_index

X_train = train_data.drop(columns=['Date ', 'Open ', 'High ', 'Low ',
       'Close '])
y_train = train_data['Close ']
X_test = test_data.drop(columns=['Date ', 'Open ', 'High ', 'Low ',
       'Close '])
y_test = test_data['Close ']

# %%
X_train
# Out:
#      Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  High _lag1  \
# 0      14253.75    14240.95    14075.15    14104.35    13996.10    14256.25
# 1      14258.40    14253.75    14240.95    14075.15    14104.35    14367.30
# 2      14474.05    14258.40    14253.75    14240.95    14075.15    14498.20
# 3      14473.80    14474.05    14258.40    14253.75    14240.95    14590.65
# 4      14639.80    14473.80    14474.05    14258.40    14253.75    14653.35
# ..          ...         ...         ...         ...         ...         ...
# 570    17950.40    17813.10    17767.30    17761.55    17707.55    18089.15
# 571    18124.80    17950.40    17813.10    17767.30    17761.55    18180.25
# 572    18113.80    18124.80    17950.40    17813.10    17767.30    18116.35
# 573    18081.00    18113.80    18124.80    17950.40    17813.10    18267.45
# 574    18117.30    18081.00    18113.80    18124.80    17950.40    18216.95
#
#      High _lag2  High _lag3  High _lag4  High _lag5  Low _lag1  Low _lag2  \
# 0      14244.15    14215.60    14147.95    14049.85   14123.10   14039.90
# 1      14256.25    14244.15    14215.60    14147.95   14221.65   14123.10
# 2      14367.30    14256.25    14244.15    14215.60   14383.10   14221.65
# 3      14498.20    14367.30    14256.25    14244.15   14432.85   14383.10
# 4      14590.65    14498.20    14367.30    14256.25   14435.70   14432.85
# ..          ...         ...         ...         ...        ...        ...
# 570    17931.60    17827.75    17807.45    17754.50   17885.30   17797.90
# 571    18089.15    17931.60    17827.75    17807.45   18101.75   17885.30
# 572    18180.25    18089.15    17931.60    17827.75   18042.40   18101.75
# 573    18116.35    18180.25    18089.15    17931.60   18066.70   18042.40
# 574    18267.45    18116.35    18180.25    18089.15   18055.45   18066.70
#
#      Low _lag3  Low _lag4  Low _lag5  Close _lag1  Close _lag2  Close _lag3  \
# 0     14048.15   13953.75   13991.35     14137.35     14146.25     14199.50
# 1     14039.90   14048.15   13953.75     14347.25     14137.35     14146.25
# 2     14123.10   14039.90   14048.15     14484.75     14347.25     14137.35
# 3     14221.65   14123.10   14039.90     14563.45     14484.75     14347.25
# 4     14383.10   14221.65   14123.10     14564.85     14563.45     14484.75
# ..         ...        ...        ...          ...          ...          ...
# 570   17711.20   17716.85   17612.50     18065.00     17915.05     17813.60
# 571   17797.90   17711.20   17716.85     18147.65     18065.00     17915.05
# 572   17885.30   17797.90   17711.20     18089.85     18147.65     18065.00
# 573   18101.75   17885.30   17797.90     18255.80     18089.85     18147.65
# 574   18042.40   18101.75   17885.30     18069.00     18255.80     18089.85
#
#      Close _lag4  Close _lag5
# 0       14132.90     14018.50
# 1       14199.50     14132.90
# 2       14146.25     14199.50
# 3       14137.35     14146.25
# 4       14347.25     14137.35
# ..           ...          ...
# 570     17769.25     17743.40
# 571     17813.60     17769.25
# 572     17915.05     17813.60
# 573     18065.00     17915.05
# 574     18147.65     18065.00
#
# [575 rows x 20 columns]

# %%
X_test
# Out:
#      Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  High _lag1  \
# 0      18339.30    18273.75    18357.80    18313.60    18303.40    18458.90
# 1      18432.35    18339.30    18273.75    18357.80    18313.60    18432.35
# 2      18300.45    18432.35    18339.30    18273.75    18357.80    18309.00
# 3      18287.50    18300.45    18432.35    18339.30    18273.75    18297.20
# 4      18186.15    18287.50    18300.45    18432.35    18339.30    18218.10
# ..          ...         ...         ...         ...         ...         ...
# 190    21906.55    21578.15    21664.30    21800.80    21727.00    21953.85
# 191    22020.30    21906.55    21578.15    21664.30    21800.80    22068.65
# 192    22103.45    22020.30    21906.55    21578.15    21664.30    22186.65
# 193    22099.20    22103.45    22020.30    21906.55    21578.15    22215.60
# 194    22248.85    22099.20    22103.45    22020.30    21906.55    22249.40
#
#      High _lag2  High _lag3  High _lag4  High _lag5  Low _lag1  Low _lag2  \
# 0      18342.75    18389.70    18326.75    18344.20   18287.90   18194.55
# 1      18458.90    18342.75    18389.70    18326.75   18264.35   18287.90
# 2      18432.35    18458.90    18342.75    18389.70   18115.35   18264.35
# 3      18309.00    18432.35    18458.90    18342.75   18104.85   18115.35
# 4      18297.20    18309.00    18432.35    18458.90   18060.40   18104.85
# ..          ...         ...         ...         ...        ...        ...
# 190    21870.85    21766.80    21831.70    21804.45   21794.80   21530.20
# 191    21953.85    21870.85    21766.80    21831.70   21968.95   21794.80
# 192    22068.65    21953.85    21870.85    21766.80   22021.05   21968.95
# 193    22186.65    22068.65    21953.85    21870.85   22045.85   22021.05
# 194    22215.60    22186.65    22068.65    21953.85   21997.95   22045.85
#
#      Low _lag3  Low _lag4  Low _lag5  Close _lag1  Close _lag2  Close _lag3  \
# 0     18270.40   18211.95   18229.65     18398.85     18314.80     18297.00
# 1     18194.55   18270.40   18211.95     18286.50     18398.85     18314.80
# 2     18287.90   18194.55   18270.40     18181.75     18286.50     18398.85
# 3     18264.35   18287.90   18194.55     18129.95     18181.75     18286.50
# 4     18115.35   18264.35   18287.90     18203.40     18129.95     18181.75
# ..         ...        ...        ...          ...          ...          ...
# 190   21543.35   21574.75   21629.90     21910.75     21840.05     21743.25
# 191   21530.20   21543.35   21574.75     22040.70     21910.75     21840.05
# 192   21794.80   21530.20   21543.35     22122.25     22040.70     21910.75
# 193   21968.95   21794.80   21530.20     22196.95     22122.25     22040.70
# 194   22021.05   21968.95   21794.80     22055.05     22196.95     22122.25
#
#      Close _lag4  Close _lag5
# 0       18315.10     18265.95
# 1       18297.00     18315.10
# 2       18314.80     18297.00
# 3       18398.85     18314.80
# 4       18286.50     18398.85
# ..           ...          ...
# 190     21616.05     21782.50
# 191     21743.25     21616.05
# 192     21840.05     21743.25
# 193     21910.75     21840.05
# 194     22040.70     21910.75
#
# [195 rows x 20 columns]

# %%
y_train
# Out:
# 0      14347.25
# 1      14484.75
# 2      14563.45
# 3      14564.85
# 4      14595.60
#          ...
# 570    18147.65
# 571    18089.85
# 572    18255.80
# 573    18069.00
# 574    18264.40
# Name: Close , Length: 575, dtype: float64

# %% [markdown]
# no norm

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Fit Ridge regression model
ridge_model = Ridge(alpha=2.0)
ridge_model.fit(X_train, y_train)

# Fit Lasso regression model
lasso_model = Lasso(alpha=2.0)
lasso_model.fit(X_train, y_train)

# Predictions
y_pred_ridge = ridge_model.predict(X_test)
y_pred_lasso = lasso_model.predict(X_test)



# Evaluate
ridge_mse = mean_squared_error(y_test, y_pred_ridge)
lasso_mse = mean_squared_error(y_test, y_pred_lasso)

# Calculate RMSE
ridge_rmse = mean_squared_error(y_test, y_pred_ridge,squared = False)
lasso_rmse = mean_squared_error(y_test, y_pred_lasso,squared = False)

print("Ridge Mean Squared Error:", ridge_mse)
print("Lasso Mean Squared Error:", lasso_mse)

print("Ridge Root Mean Squared Error:", ridge_rmse)
print("Lasso Roor Mean Squared Error:", lasso_rmse)
# Out:
# Ridge Mean Squared Error: 18978.222229924326
# Lasso Mean Squared Error: 18180.829961874762
# Ridge Root Mean Squared Error: 137.7614685967173
# Lasso Roor Mean Squared Error: 134.8363080252302
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.641e+06, tolerance: 8.187e+04
#   model = cd_fast.enet_coordinate_descent(

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Ridge regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test, label='Actual', color='blue')  # Convert Series to NumPy array using .values
plt.plot(y_pred_ridge, label='Predicted (Ridge)', color='red')
plt.title('Actual vs. Predicted Values (Ridge Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('ridge_lag3(no norm).png')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Fit Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Predictions
y_pred_linear = linear_model.predict(X_test)


# Evaluate
linear_mse = mean_squared_error(y_test, y_pred_linear)
linear_rmse = mean_squared_error(y_test, y_pred_linear, squared=False)

print("Linear Regression Mean Squared Error:", linear_mse)
print("Linear Regression Root Mean Squared Error:", linear_rmse)
# Out:
# Linear Regression Mean Squared Error: 18978.222620204804
# Linear Regression Root Mean Squared Error: 137.76147001322542

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Linear Regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test, label='Actual', color='blue')
plt.plot(y_pred_linear, label='Predicted (Linear Regression)', color='red')
plt.title('Actual vs. Predicted Values (Linear Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('LR_lag3(no_norm).png')
plt.show()

# %% [markdown]
# **NORM**

# %%
train_index.columns
# Out:
# Index(['Date ', 'Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
#        'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
#        'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
#        'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
#        'Close _lag5', 'Open ', 'High ', 'Low ', 'Close '],
#       dtype='object')

# %%
columns_to_normalize = ['Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
       'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
       'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
       'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
       'Close _lag5', 'Open ', 'High ', 'Low ', 'Close ']
min_val=13596.75
max_val=22252.5
# Normalize each column separately
for column in columns_to_normalize:
  train_index[column] = (train_index[column] - min_val) / (max_val - min_val)
# Out:
# <ipython-input-178-7ac80cefe9f6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_index[column] = (train_index[column] - min_val) / (max_val - min_val)

# %%
train_index
# Out:
#          Date   Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  \
# 0   2021-01-08    0.075903    0.074425    0.055270    0.058643    0.046137
# 1   2021-01-11    0.076441    0.075903    0.074425    0.055270    0.058643
# 2   2021-01-12    0.101355    0.076441    0.075903    0.074425    0.055270
# 3   2021-01-13    0.101326    0.101355    0.076441    0.075903    0.074425
# 4   2021-01-14    0.120504    0.101326    0.101355    0.076441    0.075903
# ..         ...         ...         ...         ...         ...         ...
# 570 2023-05-02    0.502978    0.487116    0.481824    0.481160    0.474921
# 571 2023-05-03    0.523126    0.502978    0.487116    0.481824    0.481160
# 572 2023-05-04    0.521855    0.523126    0.502978    0.487116    0.481824
# 573 2023-05-05    0.518066    0.521855    0.523126    0.502978    0.487116
# 574 2023-05-08    0.522260    0.518066    0.521855    0.523126    0.502978
#
#      High _lag1  High _lag2  High _lag3  High _lag4  ...  Low _lag5  \
# 0      0.076192    0.074794    0.071496    0.063680  ...   0.045588
# 1      0.089022    0.076192    0.074794    0.071496  ...   0.041244
# 2      0.104145    0.089022    0.076192    0.074794  ...   0.052150
# 3      0.114825    0.104145    0.089022    0.076192  ...   0.051197
# 4      0.122069    0.114825    0.104145    0.089022  ...   0.060809
# ..          ...         ...         ...         ...  ...        ...
# 570    0.519008    0.500806    0.488808    0.486463  ...   0.463940
# 571    0.529532    0.519008    0.500806    0.488808  ...   0.475996
# 572    0.522150    0.529532    0.519008    0.500806  ...   0.475343
# 573    0.539607    0.522150    0.529532    0.519008  ...   0.485359
# 574    0.533772    0.539607    0.522150    0.529532  ...   0.495457
#
#      Close _lag1  Close _lag2  Close _lag3  Close _lag4  Close _lag5  \
# 0       0.062456     0.063484     0.069636     0.061941     0.048725
# 1       0.086705     0.062456     0.063484     0.069636     0.061941
# 2       0.102591     0.086705     0.062456     0.063484     0.069636
# 3       0.111683     0.102591     0.086705     0.062456     0.063484
# 4       0.111845     0.111683     0.102591     0.086705     0.062456
# ..           ...          ...          ...          ...          ...
# 570     0.516218     0.498894     0.487173     0.482050     0.479063
# 571     0.525766     0.516218     0.498894     0.487173     0.482050
# 572     0.519088     0.525766     0.516218     0.498894     0.487173
# 573     0.538261     0.519088     0.525766     0.516218     0.498894
# 574     0.516680     0.538261     0.519088     0.525766     0.516218
#
#         Open      High       Low     Close
# 0    0.076441  0.089022  0.072195  0.086705
# 1    0.101355  0.104145  0.090847  0.102591
# 2    0.101326  0.114825  0.096595  0.111683
# 3    0.120504  0.122069  0.096924  0.111845
# 4    0.110135  0.117962  0.101060  0.115397
# ..        ...       ...       ...       ...
# 570  0.523126  0.529532  0.520463  0.525766
# 571  0.521855  0.522150  0.513607  0.519088
# 572  0.518066  0.539607  0.516414  0.538261
# 573  0.522260  0.533772  0.515114  0.516680
# 574  0.522641  0.541859  0.520296  0.539254
#
# [575 rows x 25 columns]

# %%
columns_to_normalize = ['Open _lag1', 'Open _lag2', 'Open _lag3', 'Open _lag4',
       'Open _lag5', 'High _lag1', 'High _lag2', 'High _lag3', 'High _lag4',
       'High _lag5', 'Low _lag1', 'Low _lag2', 'Low _lag3', 'Low _lag4',
       'Low _lag5', 'Close _lag1', 'Close _lag2', 'Close _lag3', 'Close _lag4',
       'Close _lag5', 'Open ', 'High ', 'Low ', 'Close ']
min_val=13596.75
max_val=22252.5
# Normalize each column separately
for column in columns_to_normalize:
  test_index[column] = (test_index[column] - min_val) / (max_val - min_val)
# Out:
# <ipython-input-180-a618ff26c640>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_index[column] = (test_index[column] - min_val) / (max_val - min_val)

# %%
test_index
# Out:
#          Date   Open _lag1  Open _lag2  Open _lag3  Open _lag4  Open _lag5  \
# 0   2023-05-16    0.547907    0.540334    0.550045    0.544938    0.543760
# 1   2023-05-17    0.558658    0.547907    0.540334    0.550045    0.544938
# 2   2023-05-18    0.543419    0.558658    0.547907    0.540334    0.550045
# 3   2023-05-19    0.541923    0.543419    0.558658    0.547907    0.540334
# 4   2023-05-22    0.530214    0.541923    0.543419    0.558658    0.547907
# ..         ...         ...         ...         ...         ...         ...
# 190 2024-02-16    0.960032    0.922092    0.932045    0.947815    0.939289
# 191 2024-02-19    0.973174    0.960032    0.922092    0.932045    0.947815
# 192 2024-02-20    0.982780    0.973174    0.960032    0.922092    0.932045
# 193 2024-02-21    0.982289    0.982780    0.973174    0.960032    0.922092
# 194 2024-02-22    0.999578    0.982289    0.982780    0.973174    0.960032
#
#      High _lag1  High _lag2  High _lag3  High _lag4  ...  Low _lag5  \
# 0      0.561725    0.548306    0.553730    0.546458  ...   0.535240
# 1      0.558658    0.561725    0.548306    0.553730  ...   0.533195
# 2      0.544407    0.558658    0.561725    0.548306  ...   0.539947
# 3      0.543044    0.544407    0.558658    0.561725  ...   0.531184
# 4      0.533905    0.543044    0.544407    0.558658  ...   0.541969
# ..          ...         ...         ...         ...  ...        ...
# 190    0.965497    0.955908    0.943887    0.951385  ...   0.928071
# 191    0.978760    0.965497    0.955908    0.943887  ...   0.921699
# 192    0.992392    0.978760    0.965497    0.955908  ...   0.918072
# 193    0.995737    0.992392    0.978760    0.965497  ...   0.916553
# 194    0.999642    0.995737    0.992392    0.978760  ...   0.947122
#
#      Close _lag1  Close _lag2  Close _lag3  Close _lag4  Close _lag5  \
# 0       0.554787     0.545077     0.543021     0.545112     0.539433
# 1       0.541807     0.554787     0.545077     0.543021     0.545112
# 2       0.529706     0.541807     0.554787     0.545077     0.543021
# 3       0.523721     0.529706     0.541807     0.554787     0.545077
# 4       0.532207     0.523721     0.529706     0.541807     0.554787
# ..           ...          ...          ...          ...          ...
# 190     0.960518     0.952350     0.941166     0.926471     0.945701
# 191     0.975531     0.960518     0.952350     0.941166     0.926471
# 192     0.984952     0.975531     0.960518     0.952350     0.941166
# 193     0.993582     0.984952     0.975531     0.960518     0.952350
# 194     0.977189     0.993582     0.984952     0.975531     0.960518
#
#         Open      High       Low     Close
# 0    0.558658  0.558658  0.539248  0.541807
# 1    0.543419  0.544407  0.522034  0.529706
# 2    0.541923  0.543044  0.520821  0.523721
# 3    0.530214  0.533905  0.515686  0.532207
# 4    0.531941  0.547440  0.529371  0.545031
# ..        ...       ...       ...       ...
# 190  0.973174  0.978760  0.967241  0.975531
# 191  0.982780  0.992392  0.973261  0.984952
# 192  0.982289  0.995737  0.976126  0.993582
# 193  0.999578  0.999642  0.970592  0.977189
# 194  0.980250  1.000000  0.956416  0.995951
#
# [195 rows x 25 columns]

# %%
def denormalize(data, min_val, max_val):
    """
    Denormalizes the data using min-max normalization parameters.

    Parameters:
        data (pandas.Series or pandas.DataFrame): The normalized data to denormalize.
        min_val (float): The minimum value used for normalization.
        max_val (float): The maximum value used for normalization.

    Returns:
        pandas.Series or pandas.DataFrame: The denormalized data.
    """
    return data * (max_val - min_val) + min_val

# %%
train_data = train_index
test_data = test_index

X_train = train_data.drop(columns=['Date ', 'Open ', 'High ', 'Low ',
       'Close '])
y_train = train_data['Close ']
X_test = test_data.drop(columns=['Date ', 'Open ', 'High ', 'Low ',
       'Close '])
y_test = test_data['Close ']

# %%
# Fit Ridge regression model
ridge_model = Ridge(alpha=2.0)
ridge_model.fit(X_train, y_train)

# Fit Lasso regression model
lasso_model = Lasso(alpha=2.0)
lasso_model.fit(X_train, y_train)

# Predictions
y_pred_ridge = ridge_model.predict(X_test)
y_pred_lasso = lasso_model.predict(X_test)

#deormalize
y_pred_ridge_denormalized = denormalize(y_pred_ridge, min_val, max_val)
y_pred_lasso_denormalized = denormalize(y_pred_lasso, min_val, max_val)

# Denormalize the actual values
y_test_denormalized = denormalize(y_test, min_val, max_val)

# Evaluate
ridge_mse = mean_squared_error(y_test_denormalized, y_pred_ridge_denormalized)
lasso_mse = mean_squared_error(y_test_denormalized, y_pred_lasso_denormalized)

# Calculate RMSE
ridge_rmse = mean_squared_error(y_test_denormalized, y_pred_ridge_denormalized,squared = False)
lasso_rmse = mean_squared_error(y_test_denormalized, y_pred_lasso_denormalized,squared = False)

print("Ridge Mean Squared Error:", ridge_mse)
print("Lasso Mean Squared Error:", lasso_mse)

print("Ridge Root Mean Squared Error:", ridge_rmse)
print("Lasso Roor Mean Squared Error:", lasso_rmse)
# Out:
# Ridge Mean Squared Error: 42442.465716431994
# Lasso Mean Squared Error: 11370531.742758587
# Ridge Root Mean Squared Error: 206.01569288875058
# Lasso Roor Mean Squared Error: 3372.0219072180694

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Ridge regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test_denormalized.values, label='Actual', color='blue')  # Convert Series to NumPy array using .values
plt.plot(y_pred_ridge_denormalized, label='Predicted (Ridge)', color='red')
plt.title('Actual vs. Predicted Values (Ridge Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('norm_ridge_lag5.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Ridge regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test_denormalized.values, label='Actual', color='blue')  # Convert Series to NumPy array using .values
plt.plot(y_pred_lasso_denormalized, label='Predicted (Lasso)', color='red')
plt.title('Actual vs. Predicted Values (Ridge Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('norm_lasso_lag5.png')
plt.show()

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# Define alpha values to search
alphas = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
# Define l1_ratio values to search
l1_ratios = [0.1, 0.3, 0.5, 0.7, 0.9]

# Grid Search for Elastic Net regression
param_grid = {'alpha': alphas, 'l1_ratio': l1_ratios}
elastic_net_grid_search = GridSearchCV(ElasticNet(), param_grid, cv=5, scoring='neg_mean_squared_error')
elastic_net_grid_search.fit(X_train, y_train)

# Best alpha and l1_ratio for Elastic Net
best_alpha_elastic_net = elastic_net_grid_search.best_params_['alpha']
best_l1_ratio_elastic_net = elastic_net_grid_search.best_params_['l1_ratio']

# Fit Elastic Net regression model with best alpha and l1_ratio
elastic_net_model = ElasticNet(alpha=best_alpha_elastic_net, l1_ratio=best_l1_ratio_elastic_net)
elastic_net_model.fit(X_train, y_train)

# Predictions
y_pred_elastic_net = elastic_net_model.predict(X_test)

#Denormalize
y_pred_elastic_net_denormalized = denormalize(y_pred_elastic_net, min_val, max_val)

# Denormalize the actual values
y_test_denormalized = denormalize(y_test, min_val, max_val)

# Evaluate
elastic_net_mse = mean_squared_error(y_test_denormalized, y_pred_elastic_net_denormalized)
elastic_net_rmse = mean_squared_error(y_test_denormalized, y_pred_elastic_net_denormalized, squared=False)

print("Elastic Net Mean Squared Error:", elastic_net_mse)
print("Elastic Net Root Mean Squared Error:", elastic_net_rmse)
print("Best alpha for Elastic Net:", best_alpha_elastic_net)
print("Best l1_ratio for Elastic Net:", best_l1_ratio_elastic_net)
# Out:
# Elastic Net Mean Squared Error: 30936.80189231286
# Elastic Net Root Mean Squared Error: 175.88860648806352
# Best alpha for Elastic Net: 0.001
# Best l1_ratio for Elastic Net: 0.1

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Elastic Net regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test_denormalized.values, label='Actual', color='blue')
plt.plot(y_pred_elastic_net_denormalized, label='Predicted (Elastic Net)', color='red')
plt.title('Actual vs. Predicted Values (Elastic Net Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('NORM EN_lag5.png')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Fit Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Predictions
y_pred_linear = linear_model.predict(X_test)

#deormalize
y_pred_linear_denormalized = denormalize(y_pred_linear, min_val, max_val)

# Denormalize the actual values
y_test_denormalized = denormalize(y_test, min_val, max_val)

# Evaluate
linear_mse = mean_squared_error(y_test_denormalized, y_pred_linear_denormalized)
linear_rmse = mean_squared_error(y_test_denormalized, y_pred_linear_denormalized, squared=False)

print("Linear Regression Mean Squared Error:", linear_mse)
print("Linear Regression Root Mean Squared Error:", linear_rmse)
# Out:
# Linear Regression Mean Squared Error: 18978.222620205084
# Linear Regression Root Mean Squared Error: 137.76147001322641

# %%
import matplotlib.pyplot as plt

# Plot actual vs. predicted values for Linear Regression
plt.figure(figsize=(10, 6),dpi=300)
plt.plot(y_test_denormalized.values, label='Actual', color='blue')
plt.plot(y_pred_linear_denormalized, label='Predicted (Linear Regression)', color='red')
plt.title('Actual vs. Predicted Values (Linear Regression)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.savefig('norm LR_lag5.png')
plt.show()
